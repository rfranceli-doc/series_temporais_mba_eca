# %%
#Prompt:
#acesse o https://github.com/rfranceli-doc/series_temporais_mba_eca, capture os dados do arquivo 00.BaseVolume.xlsx (Planilha2)

import pandas as pd

# Construct the raw GitHub URL for the Excel file
excel_url = 'https://raw.githubusercontent.com/rfranceli-doc/series_temporais_mba_eca/main/00.BaseVolume.xlsx'

# Read the Excel file into a pandas DataFrame, specifying the sheet name
try:
    df_volume = pd.read_excel(excel_url, sheet_name='Planilha2')
    print("Dados da Planilha2 carregados com sucesso:")
    print(df_volume.head())
except Exception as e:
    print(f"Ocorreu um erro ao carregar o arquivo ou a planilha: {e}")
# Out:
# Dados da Planilha2 carregados com sucesso:
#     Usuários  Clientes Cativo - Residencial Individual  \
# 0 2018-06-01                                   1213427
# 1 2018-07-01                                   1226778
# 2 2018-08-01                                   1231764
# 3 2018-09-01                                   1229575
# 4 2018-10-01                                   1243986
#
#    Clientes Cativo - Residencial Coletivo  Clientes Cativo - Comercial  \
# 0                                  593175                        30238
# 1                                  598866                        30733
# 2                                  599669                        30710
# 3                                  639991                        30969
# 4                                  611396                        30602
#
#    Clientes Industrial  Clientes GNV - Postos / Transporte Público / Frotas  \
# 0                 1262                                                264
# ...

# %%
#Prompt:
#alterar os nomes dos campos, excluindo oas espaços e substituindo por _

# Replace spaces in column names with underscores
df_volume.columns = df_volume.columns.str.replace(' ', '_')

print("Nomes das colunas atualizados:")
print(df_volume.columns.tolist())
# Out:
# Nomes das colunas atualizados:
# ['Usuários', 'Clientes_Cativo_-_Residencial_Individual', 'Clientes_Cativo_-_Residencial_Coletivo', 'Clientes_Cativo_-_Comercial', 'Clientes_Industrial', 'Clientes_GNV_-_Postos_/_Transporte_Público_/_Frotas', 'Clientes_GNV_-_Postos', 'Clientes_GNV_-_Transporte_Público', 'Clientes_GNV_-_Frotas', 'Clientes_Cogeração', 'Clientes_Refrigeração', 'Clientes_GNL', 'Clientes_Interruptível', 'Clientes_Alto_Fator_de_Carga', 'Clientes_GNC', 'Clientes_Cativo_-_Termelétrica', 'Clientes_Total_Não_Térmico', 'Volume_Cativo_-_Residencial_Individual', 'Volume_Cativo_-_Residencial_Coletivo', 'Volume_Cativo_-_Comercial', 'Volume_Industrial', 'Volume_GNV_-_Postos_/_Transporte_Público_/_Frotas', 'Volume_GNV_-_Postos', 'Volume_GNV_-_Transporte_Público', 'Volume_GNV_-_Frotas', 'Volume_Cogeração', 'Volume_Refrigeração', 'Volume_GNL', 'Volume_Interruptível', 'Volume_Alto_Fator_de_Carga', 'Volume_GNC', 'Volume_Cativo_-_Termelétrica', 'Volume_Total_Não_Térmico']

# %%
df_volume.head()
# Out:
#     Usuários  Clientes_Cativo_-_Residencial_Individual  \
# 0 2018-06-01                                   1213427
# 1 2018-07-01                                   1226778
# 2 2018-08-01                                   1231764
# 3 2018-09-01                                   1229575
# 4 2018-10-01                                   1243986
#
#    Clientes_Cativo_-_Residencial_Coletivo  Clientes_Cativo_-_Comercial  \
# 0                                  593175                        30238
# 1                                  598866                        30733
# 2                                  599669                        30710
# 3                                  639991                        30969
# 4                                  611396                        30602
#
#    Clientes_Industrial  Clientes_GNV_-_Postos_/_Transporte_Público_/_Frotas  \
# 0                 1262                                                264
# ...

# %%
print(df_volume.head())
# Out:
#     Usuários  Clientes_Cativo_-_Residencial_Individual  \
# 0 2018-06-01                                   1213427
# 1 2018-07-01                                   1226778
# 2 2018-08-01                                   1231764
# 3 2018-09-01                                   1229575
# 4 2018-10-01                                   1243986
#
#    Clientes_Cativo_-_Residencial_Coletivo  Clientes_Cativo_-_Comercial  \
# 0                                  593175                        30238
# 1                                  598866                        30733
# 2                                  599669                        30710
# 3                                  639991                        30969
# 4                                  611396                        30602
#
#    Clientes_Industrial  Clientes_GNV_-_Postos_/_Transporte_Público_/_Frotas  \
# 0                 1262                                                264
# ...

# %%
#Prompt:
#altere o nome da coluna Usuários para Data

df_volume = df_volume.rename(columns={'Usuários': 'Data'})
print("Coluna 'Usuários' renomeada para 'Data'.")
print(df_volume.head())
# Out:
# Coluna 'Usuários' renomeada para 'Data'.
#         Data  Clientes_Cativo_-_Residencial_Individual  \
# 0 2018-06-01                                   1213427
# 1 2018-07-01                                   1226778
# 2 2018-08-01                                   1231764
# 3 2018-09-01                                   1229575
# 4 2018-10-01                                   1243986
#
#    Clientes_Cativo_-_Residencial_Coletivo  Clientes_Cativo_-_Comercial  \
# 0                                  593175                        30238
# 1                                  598866                        30733
# 2                                  599669                        30710
# 3                                  639991                        30969
# 4                                  611396                        30602
#
#    Clientes_Industrial  Clientes_GNV_-_Postos_/_Transporte_Público_/_Frotas  \
# 0                 1262                                                264
# ...

# %%
#Prompt:
#plote o campo Volume_Industrial, incorpore a quantidade de clientes industrias (Clientes_Industrial), no tempo, utilize o campo Data

import matplotlib.pyplot as plt
import pandas as pd

# Ensure 'Data' column is in datetime format
df_volume['Data'] = pd.to_datetime(df_volume['Data'])

# Create the plot
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot Volume_Industrial on the first y-axis
ax1.plot(df_volume['Data'], df_volume['Volume_Industrial'], color='tab:blue', label='Volume Industrial')
ax1.set_xlabel('Data')
ax1.set_ylabel('Volume Industrial', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Create a second y-axis for Clientes_Industrial
ax2 = ax1.twinx()
ax2.plot(df_volume['Data'], df_volume['Clientes_Industrial'], color='tab:red', label='Clientes Industrial')
ax2.set_ylabel('Clientes Industrial', color='tab:red')
ax2.tick_params(axis='y', labelcolor='tab:red')

# Add title and legend
plt.title('Volume Industrial e Clientes Industrial ao longo do Tempo')
fig.tight_layout() # Adjust layout to prevent labels from overlapping

# Combine legends from both axes
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper left')

plt.show()

# %%
#Prompt:
#plote o campo Volume_Cativo_-_Residencial_Coletivo, utilize no tempo o campo Data, e incorpore o campo Clientes_Cativo_-_Residencial_Coletivo

import matplotlib.pyplot as plt
import pandas as pd

# Ensure 'Data' column is in datetime format
df_volume['Data'] = pd.to_datetime(df_volume['Data'])

# Create the plot
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot Volume_Cativo_-_Residencial_Coletivo on the first y-axis
ax1.plot(df_volume['Data'], df_volume['Volume_Cativo_-_Residencial_Coletivo'], color='tab:blue', label='Volume Residencial Coletivo')
ax1.set_xlabel('Data')
ax1.set_ylabel('Volume Residencial Coletivo', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Create a second y-axis for Clientes_Cativo_-_Residencial_Coletivo
ax2 = ax1.twinx()
ax2.plot(df_volume['Data'], df_volume['Clientes_Cativo_-_Residencial_Coletivo'], color='tab:red', label='Clientes Residencial Coletivo')
ax2.set_ylabel('Clientes Residencial Coletivo', color='tab:red')
ax2.tick_params(axis='y', labelcolor='tab:red')

# Add title and legend
plt.title('Volume e Clientes Residencial Coletivo ao longo do Tempo')
fig.tight_layout() # Adjust layout to prevent labels from overlapping

# Combine legends from both axes
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper left')

plt.show()

# %%
#Prompt:
#gere uma série dividindo o volume Volume_Cativo_-Residencial_Coletivo por 'Clientes_Cativo-_Residencial_Coletivo, chame de volume_por_cliente_coletivo
df_volume['volume_por_cliente_coletivo'] = df_volume['Volume_Cativo_-_Residencial_Coletivo'] / df_volume['Clientes_Cativo_-_Residencial_Coletivo']
print(df_volume[['Data', 'Volume_Cativo_-_Residencial_Coletivo', 'Clientes_Cativo_-_Residencial_Coletivo', 'volume_por_cliente_coletivo']].head())
# Out:
#         Data  Volume_Cativo_-_Residencial_Coletivo  \
# 0 2018-06-01                           12389809.89
# 1 2018-07-01                           11966696.24
# 2 2018-08-01                           12583762.49
# 3 2018-09-01                           13204783.68
# 4 2018-10-01                           11707935.16
#
#    Clientes_Cativo_-_Residencial_Coletivo  volume_por_cliente_coletivo
# 0                                  593175                    20.887276
# 1                                  598866                    19.982260
# 2                                  599669                    20.984514
# 3                                  639991                    20.632765
# 4                                  611396                    19.149512

# %%
#Prompt:
#plote volume_por_cliente_coletivo, utilizando a data no tempo

import matplotlib.pyplot as plt
import pandas as pd

# Ensure 'Data' column is in datetime format, although it should already be from previous steps
df_volume['Data'] = pd.to_datetime(df_volume['Data'])

# Create the plot
plt.figure(figsize=(12, 6))
plt.plot(df_volume['Data'], df_volume['volume_por_cliente_coletivo'], color='blue')
plt.xlabel('Data')
plt.ylabel('Volume por Cliente Coletivo')
plt.title('Volume por Cliente Coletivo ao longo do Tempo')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#Prompt:
#faça uma decomposição aditiva da série temporal Volume_Industrial
import statsmodels.api as sm

# Set 'Data' column as index for time series decomposition
df_volume_indexed = df_volume.set_index('Data')

# Decompose the 'Volume_Industrial' series
# Assuming monthly data, a period of 12 is appropriate for yearly seasonality
decomposition_industrial = sm.tsa.seasonal_decompose(df_volume_indexed['Volume_Industrial'], model='additive', period=12)

# Plot the decomposed components
fig = decomposition_industrial.plot()
fig.set_size_inches(10, 8)
fig.suptitle('Decomposição da Série Temporal: Volume_Industrial', y=1.02) # Adjust title position
plt.tight_layout()
plt.show()

# %%
#Prompt:
#faça a decomposição aditiva da série volume_por_cliente_coletivo

import statsmodels.api as sm
import matplotlib.pyplot as plt

# Ensure 'Data' column is set as index
df_volume_indexed = df_volume.set_index('Data')

# Decompose the 'volume_por_cliente_coletivo' series using an additive model
decomposition_volume_per_client = sm.tsa.seasonal_decompose(df_volume_indexed['volume_por_cliente_coletivo'], model='additive', period=12)

# Plot the decomposed components
fig = decomposition_volume_per_client.plot()
fig.set_size_inches(10, 8)
fig.suptitle('Decomposição da Série Temporal: Volume por Cliente Coletivo', y=1.02) # Adjust title position
plt.tight_layout()
plt.show()

# %%
#Prompt:
#faça a decomposição multiplicativa da serie temporal Volume_Industrial

import statsmodels.api as sm
import matplotlib.pyplot as plt

# Ensure 'Data' column is set as index for time series decomposition
df_volume_indexed = df_volume.set_index('Data')

# Decompose the 'Volume_Industrial' series using a multiplicative model
decomposition_industrial_multiplicative = sm.tsa.seasonal_decompose(df_volume_indexed['Volume_Industrial'], model='multiplicative', period=12)

# Plot the decomposed components
fig = decomposition_industrial_multiplicative.plot()
fig.set_size_inches(10, 8)
fig.suptitle('Decomposição Multiplicativa da Série Temporal: Volume_Industrial', y=1.02) # Adjust title position
plt.tight_layout()
plt.show()

# %%
#Prompt:
#faça a decomposição multiplicativa da serie temporal VOLUME_POR_CLIENTE_COLETIVO

import statsmodels.api as sm
import matplotlib.pyplot as plt

# Ensure 'Data' column is set as index for time series decomposition
df_volume_indexed = df_volume.set_index('Data')

# Decompose the 'volume_por_cliente_coletivo' series using a multiplicative model
decomposition_volume_per_client_multiplicative = sm.tsa.seasonal_decompose(df_volume_indexed['volume_por_cliente_coletivo'], model='multiplicative', period=12)

# Plot the decomposed components
fig = decomposition_volume_per_client_multiplicative.plot()
fig.set_size_inches(10, 8)
fig.suptitle('Decomposição Multiplicativa da Série Temporal: Volume por Cliente Coletivo', y=1.02) # Adjust title position
plt.tight_layout()
plt.show()

# %%
df_volume.volume_por_cliente_coletivo.head()
# Out:
# 0    20.887276
# 1    19.982260
# 2    20.984514
# 3    20.632765
# 4    19.149512
# Name: volume_por_cliente_coletivo, dtype: float64

# %%
#Prompt:
#gere uma série suavizada do volume_por_cliente_coletivo, utilizando 12 meses

df_volume['volume_por_cliente_coletivo_suavizado'] = df_volume['volume_por_cliente_coletivo'].rolling(window=12, center=True).mean()
print(df_volume[['Data', 'volume_por_cliente_coletivo', 'volume_por_cliente_coletivo_suavizado']].head(15))
# Out:
#          Data  volume_por_cliente_coletivo  \
# 0  2018-06-01                    20.887276
# 1  2018-07-01                    19.982260
# 2  2018-08-01                    20.984514
# 3  2018-09-01                    20.632765
# 4  2018-10-01                    19.149512
# 5  2018-11-01                    18.265365
# 6  2018-12-01                    16.723279
# 7  2019-01-01                    14.487219
# 8  2019-02-01                    12.186304
# 9  2019-03-01                    14.446188
# 10 2019-04-01                    17.335315
# 11 2019-05-01                    12.890798
# 12 2019-06-01                    17.933974
# 13 2019-07-01                    19.623746
# 14 2019-08-01                    20.360127
#
#     volume_por_cliente_coletivo_suavizado
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...

# %%
#Prompt:
#plote a série 'volume_por_cliente_coletivo_suavizado'

import matplotlib.pyplot as plt

# Create the plot
plt.figure(figsize=(12, 6))
plt.plot(df_volume['Data'], df_volume['volume_por_cliente_coletivo'], label='Volume por Cliente Coletivo Original', color='blue', alpha=0.7)
plt.plot(df_volume['Data'], df_volume['volume_por_cliente_coletivo_suavizado'], label='Volume por Cliente Coletivo Suavizado (12 meses)', color='red')
plt.xlabel('Data')
plt.ylabel('Volume por Cliente Coletivo')
plt.title('Volume por Cliente Coletivo (Original e Suavizado) ao longo do Tempo')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#O erro que estava acontecendo
#A IA pegou a série 'volume_por_cliente_coletivo_suavizado'
#Essa séria tem NAs, por isso ela nãop calculou a suavização.
#Abaixo está a série corrigida


import matplotlib.pyplot as plt
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
import pandas as pd

df_clean = df_volume[['Data','volume_por_cliente_coletivo_suavizado']]
df_clean = df_clean.set_index('Data')

# Ajustar o modelo SES (Alpha = 0.2 como padrão, pode ser ajustado)
model_ses = SimpleExpSmoothing(df_clean['volume_por_cliente_coletivo_suavizado'], initialization_method='estimated').fit(smoothing_level=0.2, optimized=False)


# Adicionar os valores ajustados ao DataFrame original
df_volume['volume_por_cliente_coletivo_ses'] = df_volume['Data'].map(model_ses.fittedvalues.to_dict())

# Plotagem
plt.figure(figsize=(12, 6))
plt.plot(df_volume['Data'], df_volume['volume_por_cliente_coletivo'], label='Original (Volume por Cliente Coletivo)', color='blue', alpha=0.5)
plt.plot(df_volume['Data'], df_volume['volume_por_cliente_coletivo_ses'], label='SES (Suavizada)', color='green', linewidth=2)
plt.xlabel('Data')
plt.ylabel('Volume por Cliente')
plt.title('Série Original vs. Suavização Exponencial Simples (SES)')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
#Prompt:
#gere uma serie temporal suavizada utilizando ses, e plot em conjunto com a série original (volume_por cliente_coletivo)
#Usei o Gemini 3

import matplotlib.pyplot as plt
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
import pandas as pd

# Preparar os dados removendo NaNs para o modelo SES
df_clean = df_volume.dropna(subset=['Data', 'volume_por_cliente_coletivo']).copy()
df_clean = df_clean.set_index('Data')

# Ajustar o modelo SES (Alpha = 0.2 como padrão, pode ser ajustado)
model_ses = SimpleExpSmoothing(df_clean['volume_por_cliente_coletivo'], initialization_method='estimated').fit(smoothing_level=0.8, optimized=False)

# Adicionar os valores ajustados ao DataFrame original
df_volume['volume_por_cliente_coletivo_ses'] = df_volume['Data'].map(model_ses.fittedvalues.to_dict())

# Plotagem
plt.figure(figsize=(12, 6))
plt.plot(df_volume['Data'], df_volume['volume_por_cliente_coletivo'], label='Original (Volume por Cliente Coletivo)', color='blue', alpha=0.5)
plt.plot(df_volume['Data'], df_volume['volume_por_cliente_coletivo_ses'], label='SES (Suavizada)', color='green', linewidth=2)
plt.xlabel('Data')
plt.ylabel('Volume por Cliente')
plt.title('Série Original vs. Suavização Exponencial Simples (SES)')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Verificar se há valores não-nulos agora
print(f"Valores preenchidos na série SES: {df_volume['volume_por_cliente_coletivo_ses'].notnull().sum()}")
# Out:
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# Valores preenchidos na série SES: 78

# %%
#Prompt:
#gere uma serie temporal suavizada utilizando ses, e plot em conjunto com a série original (volume_por cliente_coletivo)
#Usei o Gemini 3

import matplotlib.pyplot as plt
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
import pandas as pd

# Preparar os dados removendo NaNs para o modelo SES
df_clean = df_volume.dropna(subset=['Data', 'volume_por_cliente_coletivo']).copy()
df_clean = df_clean.set_index('Data')

# Ajustar o modelo SES (Alpha = 0.2 como padrão, pode ser ajustado)
model_ses = SimpleExpSmoothing(df_clean['volume_por_cliente_coletivo'], initialization_method='estimated').fit(optimized=True)

# Adicionar os valores ajustados ao DataFrame original
df_volume['volume_por_cliente_coletivo_ses'] = df_volume['Data'].map(model_ses.fittedvalues.to_dict())

# Plotagem
plt.figure(figsize=(12, 6))
plt.plot(df_volume['Data'], df_volume['volume_por_cliente_coletivo'], label='Original (Volume por Cliente Coletivo)', color='blue', alpha=0.5)
plt.plot(df_volume['Data'], df_volume['volume_por_cliente_coletivo_ses'], label='SES (Suavizada)', color='green', linewidth=2)
plt.xlabel('Data')
plt.ylabel('Volume por Cliente')
plt.title('Série Original vs. Suavização Exponencial Simples (SES)')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Verificar se há valores não-nulos agora
print(f"Valores preenchidos na série SES: {df_volume['volume_por_cliente_coletivo_ses'].notnull().sum()}")
# Out:
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# Valores preenchidos na série SES: 78

# %%
#Prompt:
#gere uma serie temporal suavizada com holt-winters, e plote em conjunto com a série original (volume_por cliente_coletivo)
from statsmodels.tsa.holtwinters import ExponentialSmoothing
import matplotlib.pyplot as plt

# Preparar os dados (garantir que o índice seja temporal e sem NaNs)
df_hw = df_volume.dropna(subset=['volume_por_cliente_coletivo']).copy()
df_hw = df_hw.set_index('Data')

# Ajustar o modelo Holt-Winters (Trend='add', Seasonal='add' para 12 meses)
# O parâmetro 'use_boxcox=True' pode ser usado se a variância aumentar com o tempo
model_hw = ExponentialSmoothing(
    df_hw['volume_por_cliente_coletivo'],
    trend='add',
    seasonal='add',
    seasonal_periods=12
).fit()

# Adicionar os valores ajustados ao DataFrame
df_volume['volume_por_cliente_coletivo_hw'] = df_volume['Data'].map(model_hw.fittedvalues.to_dict())

# Plotagem comparativa
plt.figure(figsize=(14, 7))
plt.plot(df_volume['Data'], df_volume['volume_por_cliente_coletivo'], label='Original', color='blue', alpha=0.3)
plt.plot(df_volume['Data'], df_volume['volume_por_cliente_coletivo_ses'], label='SES (Suavização Simples)', color='orange', linestyle='--')
plt.plot(df_volume['Data'], df_volume['volume_por_cliente_coletivo_hw'], label='Holt-Winters (Tendência + Sazonalidade)', color='red', linewidth=2)

plt.title('Comparação de Modelos: Original vs. SES vs. Holt-Winters')
plt.xlabel('Data')
plt.ylabel('Volume por Cliente Coletivo')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

print(f"Parâmetros do Holt-Winters:\nAlpha (nível): {model_hw.params['smoothing_level']:.4f}\nBeta (tendência): {model_hw.params['smoothing_trend']:.4f}\nGamma (sazonalidade): {model_hw.params['smoothing_seasonal']:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# Parâmetros do Holt-Winters:
# Alpha (nível): 0.2424
# Beta (tendência): 0.0000
# Gamma (sazonalidade): 0.0000
